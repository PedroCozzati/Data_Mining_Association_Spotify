# %% [markdown]
# # Mineração de Dados utilizando a metodologia CRISP-DM

# %% [markdown]
# ## 1. Introdução
#
# ### O nome Crisp-DM é uma sigla para o inglês Cross Industry Standard Process for Data Mining, que em português significa algo como “Processo Padrão Inter-Indústrias para Mineração de Dados”. O objetivo dessa metodologia é desenvolver modelos a partir da análise de informações e dados de um negócio para prever futuras falhas e soluções.
#
# ### A metodologia Crisp-DM é dividida em seis etapas fundamentais, cada uma com suas particularidades e funcionalidades.
#
# ### As três primeiras etapas tem como objetivo a coleta e organização dos dados a serem analisados, envolvendo o entedimento do negócio, dados e a preparação dos dados.

# %% [markdown]
# <img src='https://miro.medium.com/v2/resize:fit:988/0*tA5OjppLK627FfFo' width=360>

# %% [markdown]
# ###  Na imagem acima, é possível ver todas as etapas dessa metodologia, e algo interessante é que ela é um ciclo, então as etapas podem ser revistas e os processos podem ser melhorados mesmo depois de estabelecidos.

# %% [markdown]
# ## 2. Entendimento do negócio
#
# ### Objetivo do projeto:  Analisar uma amostra de dados de usuários do Spotify, que contém informações sobre o que os usuário desse serviço de Streaming escutam em suas playlists, com o objetivo de encontrar associações. Por exemplo, se o usuário assiste a música/artista X, qual a chance dele também ouvir a música/artista Y?

# %% [markdown]
# ## 3. Entendimento dos dados
#
# ### Os dados serão obtidos através do site AiCrowd, onde é possível baixar o dataset (OBS: Os dados estão sendo disponibilizados devido a um desafio proposto, os dados não podem ser utilizados para fins comerciais, ver mais em https://www.aicrowd.com/challenges/spotify-million-playlist-dataset-challenge).
#
# ### Informações da base de dados fornecidas pelo Spotify
#
# ### Genero
#  * Male: 45%
#  * Female: 54%
#  * Unspecified: 0.5%
#  * Nonbinary: 0.5%
#
# ### Idade
#  * 13-17:  10%
#  * 18-24:  43%
#  * 25-34:  31%
#  * 35-44:   9%
#  * 45-54:   4%
#  * 55+:     3%
#
# ### País
#  * US: 100%
#
# ### Estatísticas
#  - number of playlists 1000000
#  - number of tracks 66346428
#  - number of unique tracks 2262292
#  - number of unique albums 734684
#  - number of unique artists 295860
#  - number of unique titles 92944
#  - number of playlists with descriptions 18760
#  - number of unique normalized titles 17381
#  - avg playlist length 66.346428
#
# ### Formato dos dados: JSON
#
# ### Dados estruturados: Sim
#
# ### Demonstração
#
# Cada arquivo é um dicionário JSON com dois campos:
# *info* e *playlists*.
#
# ### campo `info`
# Contém informações gerais sobre o arquivo:
#
#    * **slice** - the range of slices that in in this particular file - such as 0-999
#    * ***version*** -  - the current version of the MPD (which should be v1)
#    * ***description*** - a description of the MPD
#    * ***license*** - licensing info for the MPD
#    * ***generated_on*** - a timestamp indicating when the slice was generated.
#
# ### campo `playlists`
# É uma lista que normalmente contém 1000 playlists, cada playlist é um dicionário que contém os seguintes campos:
#
# * ***pid*** - integer - playlist id - the MPD ID of this playlist. This is an integer between 0 and 999,999.
# * ***name*** - string - the name of the playlist
# * ***description*** - optional string - if present, the description given to the playlist.  Note that user-provided playlist descrptions are a relatively new feature of Spotify, so most playlists do not have descriptions.
# * ***modified_at*** - seconds - timestamp (in seconds since the epoch) when this playlist was last updated. Times are rounded to midnight GMT of the date when the playlist was last updated.
# * ***num_artists*** - the total number of unique artists for the tracks in the playlist.
# * ***num_albums*** - the number of unique albums for the tracks in the playlist
# * ***num_tracks*** - the number of tracks in the playlist
# * ***num_followers*** - the number of followers this playlist had at the time the MPD was created. (Note that the follower count does not including the playlist creator)
# * ***num_edits*** - the number of separate editing sessions. Tracks added in a two hour window are considered to be added in a single editing session.
# * ***duration_ms*** - the total duration of all the tracks in the playlist (in milliseconds)
# * ***collaborative*** -  boolean - if true, the playlist is a collaborative playlist. Multiple users may contribute tracks to a collaborative playlist.
# * ***tracks*** - an array of information about each track in the playlist. Each element in the array is a dictionary with the following fields:
#    * ***track_name*** - the name of the track
#    * ***track_uri*** - the Spotify URI of the track
#    * ***album_name*** - the name of the track's album
#    * ***album_uri*** - the Spotify URI of the album
#    * ***artist_name*** - the name of the track's primary artist
#    * ***artist_uri*** - the Spotify URI of track's primary artist
#    * ***duration_ms*** - the duration of the track in milliseconds
#    * ***pos*** - the position of the track in the playlist (zero-based)
#
# Exemplo de uma playlist no JSON:
#
#         {
#             "name": "musical",
#             "collaborative": "false",
#             "pid": 5,
#             "modified_at": 1493424000,
#             "num_albums": 7,
#             "num_tracks": 12,
#             "num_followers": 1,
#             "num_edits": 2,
#             "duration_ms": 2657366,
#             "num_artists": 6,
#             "tracks": [
#                 {
#                     "pos": 0,
#                     "artist_name": "Degiheugi",
#                     "track_uri": "spotify:track:7vqa3sDmtEaVJ2gcvxtRID",
#                     "artist_uri": "spotify:artist:3V2paBXEoZIAhfZRJmo2jL",
#                     "track_name": "Finalement",
#                     "album_uri": "spotify:album:2KrRMJ9z7Xjoz1Az4O6UML",
#                     "duration_ms": 166264,
#                     "album_name": "Dancing Chords and Fireflies"
#                 },
#                 {
#                     "pos": 1,
#                     "artist_name": "Degiheugi",
#                     "track_uri": "spotify:track:23EOmJivOZ88WJPUbIPjh6",
#                     "artist_uri": "spotify:artist:3V2paBXEoZIAhfZRJmo2jL",
#                     "track_name": "Betty",
#                     "album_uri": "spotify:album:3lUSlvjUoHNA8IkNTqURqd",
#                     "duration_ms": 235534,
#                     "album_name": "Endless Smile"
#                 },
#                 {
#                     "pos": 2,
#                     "artist_name": "Degiheugi",
#                     "track_uri": "spotify:track:1vaffTCJxkyqeJY7zF9a55",
#                     "artist_uri": "spotify:artist:3V2paBXEoZIAhfZRJmo2jL",
#                     "track_name": "Some Beat in My Head",
#                     "album_uri": "spotify:album:2KrRMJ9z7Xjoz1Az4O6UML",
#                     "duration_ms": 268050,
#                     "album_name": "Dancing Chords and Fireflies"
#                 },
#                 // 8 tracks omitted
#                 {
#                     "pos": 11,
#                     "artist_name": "Mo' Horizons",
#                     "track_uri": "spotify:track:7iwx00eBzeSSSy6xfESyWN",
#                     "artist_uri": "spotify:artist:3tuX54dqgS8LsGUvNzgrpP",
#                     "track_name": "Fever 99\u00b0",
#                     "album_uri": "spotify:album:2Fg1t2tyOSGWkVYHlFfXVf",
#                     "duration_ms": 364320,
#                     "album_name": "Come Touch The Sun"
#                 }
#             ],
#
#         }

# %% [markdown]
# ## 4. Preparação dos dados
#
# ### Os dados que serão utilizados já estão bem estruturados e documentados, o que diminui os esforços do processo de preparação e tratamento de dados. Porém algumas coisas devem ser feitas:
#
# #### 1. Eliminar nulos e playlists sem músicas
# #### 2. Reordernar dados para a estrutura csv, onde cada linha será uma playlist, exemplo:
# ID&emsp;&emsp;&emsp;, Item 1&emsp;&emsp;&emsp;&emsp;&emsp;, Item 2&emsp;&emsp;&emsp;&emsp;&emsp;, Item 3 &emsp;&emsp;&emsp;&emsp;&emsp;, Item 4&emsp;&emsp;&emsp;&emsp;&emsp;... <br>
# 1048588, artista X/musica Y, artista X/musica Z, artista X/musica Z, artista X/musica Z... <br>
# 1048589, artista X/musica Z, artista X/musica Z, artista X/musica Z, artista X/musica Z... <br>
#
# ### Visualização dos dados coletados:

# %%
import pandas as pd
import os
import numpy as np
import json
import random

# %%
arquivo = "./spotify_million_playlist_dataset/mpd.slice.843000-843999.json"
with open(arquivo, 'r') as file:
    data = json.load(file)

# Extrair a primeira playlist
primeira_playlist = data['playlists']

# Ler os dados diretamente como um DataFrame do pandas
viz = pd.json_normalize(primeira_playlist)

# Visualizar 10 primeiras linhas
viz[viz.num_tracks >0]
# Out:
#                 name collaborative     pid  modified_at  num_tracks  \
# 0           get hype         false  843000   1507161600          96
# 1    party playlist          false  843001   1499126400         136
# 2              d-.-b         false  843002   1473897600         237
# 3              sleep         false  843003   1508457600          26
# 4               1985         false  843004   1478476800          37
# ..               ...           ...     ...          ...         ...
# 995             main         false  843995   1507939200          45
# 996               ⛵️         false  843996   1506384000          89
# 997              Boi         false  843997   1505865600          24
# 998          dubstep         false  843998   1486944000          14
# 999            Go Go         false  843999   1446768000           9
#
#      num_albums  num_followers  \
# 0            72              2
# 1           105              1
# 2           192              1
# 3            22              1
# 4            30              1
# ..          ...            ...
# 995          42              1
# 996          72              1
# 997          24              1
# 998          11              1
# 999           9              1
#
#                                                 tracks  num_edits  \
# 0    [{'pos': 0, 'artist_name': 'DRAM', 'track_uri'...          6
# 1    [{'pos': 0, 'artist_name': 'Sonny Alven', 'tra...          3
# 2    [{'pos': 0, 'artist_name': 'Pac Div', 'track_u...        126
# 3    [{'pos': 0, 'artist_name': 'Drake', 'track_uri...          5
# 4    [{'pos': 0, 'artist_name': 'The Cars', 'track_...          5
# ..                                                 ...        ...
# 995  [{'pos': 0, 'artist_name': 'The All-American R...         25
# 996  [{'pos': 0, 'artist_name': 'Cage The Elephant'...         27
# 997  [{'pos': 0, 'artist_name': 'Clairo', 'track_ur...          2
# 998  [{'pos': 0, 'artist_name': 'Doctor P', 'track_...          7
# 999  [{'pos': 0, 'artist_name': 'Northeast Groovers...          6
#
#      duration_ms  num_artists description
# 0       22121466           43         NaN
# 1       31381784           74         NaN
# 2       57718299          121         NaN
# 3        6843516           13         NaN
# 4        9516934           24         NaN
# ..           ...          ...         ...
# 995      9974073           40         NaN
# 996     20134760           49         NaN
# 997      5902167           24         NaN
# 998      3285193            9         NaN
# 999      3881998            5         NaN
#
# [1000 rows x 12 columns]

# %% [markdown]
# ### Os dados atuais possuem diversas informações que não serão utilizadas no modelo de associação, sendo assim, é necessário eliminar o excesso de informações.

# %%
# O Código irá percorrer cada arquivo JSON na pasta "spotify_million_playlist_dataset", e então obter apenas o campo "playlists"

# Isso irá diminuir o tamanho do arquivo final, e facilita ao selecionar uma amostra 
# aleatória, pois o dataset já estará dividido em grupos.


playlists = []
split_playlists = []

# Diretório onde estão os arquivos JSON, somando todos os arquivos, temos 8.1GB de dados disponíveis
diretorio = "./spotify_million_playlist_dataset/"
count = 0

# Iterar sobre todos os arquivos no diretório
for arq in os.listdir(diretorio):
    if arq.endswith(".json"):
        # Carregar o arquivo JSON
        with open(os.path.join(diretorio, arq), 'r') as f:
            data = json.load(f)
            # Extrair o campo "playlists" e adicionar à lista
            all_playlists.extend(data['playlists'])
            count = count + 1
            if count> 0 and count % 10 == 0:
                split_playlists.append(playlists)
                with open(f"all_playlists_{count}.json", 'w') as f:
                    json.dump({'playlists': split_playlists}, f)
                
                all_playlists =[]
                split_playlists=[]

# O processo demorou cerca de 11 minutos, sendo que cada item ficou com cerca de 196MB.
# foram gerados 28 arquivos.
# Somando todos os arquivos, temos 5,21GB, uma economia de quase 3GB.

# %% [markdown]
# ### A próxima etapa é selecionar uma amostra, de 28 arquivos, serão selecionados 10 de forma totalmente aleatória

# %%
random_nums = list(range(10,290,10))
random.shuffle(random_nums)
# print(random_nums)
numeros_selecionados = []

for i in range(0,len(random_nums)):
    if i <= 10:
        numeros_selecionados.append(random_nums[i])

# %%
numeros_selecionados
# Out:
# [100, 120, 200, 270, 30, 60, 280, 140, 170, 40, 110]

# %% [markdown]
# ### O código seguinte passa por cada arquivo selecionado aleatoriamente e grava o conteúdo em um arquivo final com todos os dados necessário

# %%
all_playlists = []

# Diretório onde estão os arquivos JSON
diretorio = "./"

# Iterar sobre todos os arquivos no diretório
for arq in os.listdir(diretorio):
    for num in numeros_selecionados:
        if arq.endswith(".json") and '_' + str(num) in arq:
            # Carregar o arquivo JSON
            with open(os.path.join(diretorio, arq), 'r') as f:
                data = json.load(f)
                # Extrair o campo "playlists" e adicionar à lista
                all_playlists.extend(data['playlists'])
                f.close()

# Criar um novo arquivo JSON com todas as playlists
with open('all_data.json', 'w') as f:
    json.dump({'playlists': all_playlists}, f)
    f.close()

# %%
arquivo = "all_data.json"
with open(arquivo, 'r') as file:
    data = json.load(file)
    file.close()

# Extrair as playlists
playlists = data['playlists']

dataframes = [pd.json_normalize(playlist) for playlist in playlists]

dados = pd.concat(dataframes, ignore_index=True)

dados['tracks'] = dados['tracks'].apply(lambda x: [f"{track['artist_name']} / {track['track_name']}" for track in x])
dados.head(10)
# Out:
#                       name collaborative     pid  modified_at  num_tracks  \
# 0                     2016         false  823000   1509235200          77
# 1                    Fav❤️         false  823001   1503792000          99
# 2              Christmas.          false  823002   1449273600          16
# 3                 Eargasms         false  823003   1500940800          29
# 4  Noosa Tastiest Playlist         false  823004   1472774400          33
# 5                      ♡♡♡         false  823005   1493856000          35
# 6                Christmas         false  823006   1481328000          42
# 7              This Summer         false  823007   1473120000          40
# 8                   maddie         false  823008   1509408000          85
# 9                 Variado          false  823009   1476576000          33
#
#    num_albums  num_followers  \
# 0          76              1
# 1          89              1
# 2           9              1
# 3          28              1
# 4          33              1
# 5          33              2
# 6          31              2
# 7          35              1
# 8          74              1
# 9          16              1
#
#                                               tracks  num_edits  duration_ms  \
# 0  [Jon Bellion / All Time Low, Tatiana Manaois /...         17     16680321
# 1  [Petit Biscuit / Sunset Lover, Jai Wolf / Indi...         51     22127129
# 2  [Michael Bublé / I'll Be Home For Christmas, M...          3      3055529
# 3  [Dillon Francis / Coming Over (feat. James Her...         21      6292781
# 4  [Lee Brice / Hard To Love, Dustin Lynch / Hell...          2      7160167
# 5  [Train / Drops of Jupiter, Plain White T's / H...         11      8030962
# 6  [Kenny Loggins / Celebrate Me Home, Josh Groba...          8      9132652
# 7  [Squeeze / This Summer, Ra Ra Riot / Water, Sl...         28      8904808
# 8  [Drake / One Dance, Rihanna / Work, Drake / Ju...         48     19047362
# 9  [Francisco Céspedes / Todo es un misterio, Fra...          6      8251439
#
#    num_artists description
# 0           75         NaN
# 1           78         NaN
# 2           12         NaN
# 3           25         NaN
# 4           33         NaN
# 5           32         NaN
# 6           29         NaN
# 7           28         NaN
# 8           62         NaN
# 9           13         NaN

# %% [markdown]
# ### Agora que os dados de amostra estão completos, é necessário analisar

# %%
dados.describe()
# Out:
#                  pid   modified_at     num_tracks     num_albums  \
# count  110000.000000  1.100000e+05  110000.000000  110000.000000
# mean   791135.863636  1.476293e+09      66.455127      49.638500
# std    233208.510047  3.673033e+07      53.677038      39.911424
# min     77000.000000  1.275437e+09       5.000000       2.000000
# 25%    777499.750000  1.458950e+09      26.000000      20.000000
# 50%    839999.500000  1.490227e+09      49.000000      37.000000
# 75%    895499.250000  1.505520e+09      92.000000      68.000000
# max    994999.000000  1.509494e+09     376.000000     242.000000
#
#        num_followers      num_edits   duration_ms    num_artists
# count  110000.000000  110000.000000  1.100000e+05  110000.000000
# mean        2.342927      17.722382  1.558836e+07      38.088755
# std        66.638100      20.659587  1.281889e+07      30.149510
# min         1.000000       1.000000  4.748380e+05       3.000000
# 25%         1.000000       5.000000  6.012931e+06      16.000000
# 50%         1.000000      10.000000  1.144368e+07      29.000000
# 75%         1.000000      22.000000  2.145740e+07      52.000000
# max     15123.000000     197.000000  1.678909e+08     222.000000

# %% [markdown]
# ### Usando apenas a análise estatística, é possível observar alguns pontos
#  - A média de músicas por playlist é de +- 66
#  - Possibilidade de outliers
#  - As playlists estão desbalanceadas, algumas possuem 30 músicas, enquanto outras possuem 300. Isso não é bom para o modelo de associação.
#
# ### Removendo outliers

# %%
# Calcular o Z-score para cada ponto de dados
dados['Z_score'] = (dados['num_tracks'] - dados['num_tracks'].mean()) / dados['num_tracks'].std()

# Identificar outliers com Z-score acima de 3 ou abaixo de -3
outliers_z_score_index = dados[(dados['Z_score'] > 3) | (dados['Z_score'] < -3)].index

# Eliminar outliers
dados_sem_outliers = dados.drop(outliers_z_score_index)
len(dados_sem_outliers)
# Out:
# 108591

# %% [markdown]
# ### Preencher dados vazios com o valor Nan, facilitando o filtro.

# %%
tracks = []

for index, row in dados_sem_outliers.iterrows():
    tracks.append(row['tracks'])

new_df = pd.DataFrame(tracks)

new_df = new_df.fillna(np.nan)

new_df.columns = [f'Track {i}' for i in range(1, len(new_df.columns) + 1)]

# %%
new_df.tail(30)
# Out:
#                                                   Track 1  \
# 108561           Adele / Send My Love (To Your New Lover)
# 108562                         Sara Bareilles / Uncharted
# 108563                   Boys Like Girls / Hero / Heroine
# 108564                              BØRNS / Electric Love
# 108565                                   San Holo / Light
# 108566                              FKA twigs / Two Weeks
# 108567                    Miley Cyrus / Hoedown Throwdown
# 108568  Hillsong Young & Free / Where You Are - Radio ...
# 108569                          Washed Out / Great Escape
# 108570                  Dustin Lynch / Cowboys and Angels
# 108571                             Tritonal / Untouchable
# 108572                            The Knife / The Captain
# 108573                        Florida Georgia Line / Stay
# 108574               Selena Gomez / Kill Em With Kindness
# 108575                                Saje / Lost Tonight
# 108576                              Kevin Gates / What If
# 108577                         Alice Cooper / I Never Cry
# 108578                         Childish Gambino / Redbone
# 108579                       Petit Biscuit / Sunset Lover
# 108580          Edward Sharpe & The Magnetic Zeros / Home
# 108581                               alt-J / Fitzpleasure
# 108582                               Drake / Marvins Room
# 108583                    Portugal. The Man / So American
# 108584                             Lil Wayne / Believe Me
# 108585  Faith Hill / Where Are You Christmas - From "D...
# 108586          Pentatonix / Somebody That I Used to Know
# 108587                      Donnie McClurkin / The Prayer
# 108588                        Trevor Hall / The Lime Tree
# 108589        Major Lazer / Lean On (feat. MØ & DJ Snake)
# 108590                   Newsboys / Your Love Never Fails
#
#                                                   Track 2  \
# 108561                                   Drake / Too Good
# 108562                         Sara Bareilles / Manhattan
# 108563                 Boys Like Girls / The Great Escape
# 108564                             Laura Veirs / Sun Song
# 108565                               Train / Working Girl
# 108566                           Pentatonix / La La Latch
# 108567                            Miley Cyrus / The Climb
# 108568               Hillsong Young & Free / Sinking Deep
# 108569                  Courtney Barnett / Avant Gardener
# 108570                           John Waite / Missing You
# 108571                              Jonas Blue / Fast Car
# 108572  The Queen of Hearts / Where Are You Now? - Sta...
# 108573                      Florida Georgia Line / Cruise
# 108574                            Justin Bieber / Company
# 108575                                  Flume / Sleepless
# 108576                                 Kid Ink / F With U
# 108577                 Christopher Cross / Think Of Laura
# 108578      Cash Cash / All My Love (feat. Conor Maynard)
# 108566                     Betty Who / Somebody Loves You
# 108567          Hannah Montana / I'll Always Remember You
# 108568  Hillsong United / Scandal Of Grace (I'd Be Los...
# 108569                                  Flume / Holdin On
# 108570                                                NaN
# 108571                 Sigala / Sweet Lovin' - Radio Edit
# 108572  Sky Ferreira / One - Totally Enormous Extinct ...
# 108573                     Jason Aldean / Feel That Again
# 108574                               Thirdstory / G Train
# 108575  G-Eazy / Some Kind Of Drug - Lincoln Jesser Remix
# 108576                       Lil Uzi Vert / XO TOUR Llif3
# 108577                                                NaN
# 108578                                 6LACK / Never Know
# 108579                          Electric Guest / Oh Devil
# 108580                 Lana Del Rey / Young And Beautiful
# 108581                              Matt Corby / Brother.
# 108582                                 Drake / Redemption
# 108583  Portugal. The Man / All Your Light (Times Like...
# 108584          2Pac / Hail Mary - Album Version (Edited)
# 108585                          Pentatonix / Silent Night
# 108586  The Sing-Off Contestants / I've Got The Music ...
# 108587  Donnie McClurkin / I Call You Faithful - (Albu...
# 108588                              Serena Ryder / Stompa
# 108589                               Misun / Battlefields
# 108590     Hillsong Young & Free / Only Wanna Sing - Live
#
#                                                  Track 10  ... Track 218  \
# 108561                                                NaN  ...       NaN
# 108562                           Sara Bareilles / Islands  ...       NaN
# 108563                  Metro Station / Seventeen Forever  ...       NaN
# 108564                      Arthur Beatrice / Grand Union  ...       NaN
# 108565                                Adam Friedman / Sad  ...       NaN
# 108566                            Mary J. Blige / Therapy  ...       NaN
# 108567                          Avril Lavigne / Sk8er Boi  ...       NaN
# 108568       Hillsong United / From the Inside Out - Live  ...       NaN
# 108569                                     HAIM / Falling  ...       NaN
# 108570                                                NaN  ...       NaN
# 108571  Jason Derulo / Try Me (feat. Jennifer Lopez & ...  ...       NaN
# 108572                                 Ssion / Luvvbazaar  ...       NaN
# 108573                      Jason Aldean / Wheels Rollin'  ...       NaN
# 108574                             Jax Jones / House Work  ...       NaN
# 108575                    Flume / Say It - Illenium Remix  ...       NaN
# 108576                               Frank Ocean / Biking  ...       NaN
# 108577                                                NaN  ...       NaN
# 108578                                                NaN  ...       NaN
# 108579                      Flight Facilities / Crave You  ...       NaN
# 108580  Kaskade / No One Knows Who We Are - Kaskade's ...  ...       NaN
# 108581                           Mura Masa / Are U There?  ...       NaN
# 108582                                   Drake / With You  ...       NaN
# 108583                  Portugal. The Man / Sleep Forever  ...       NaN
# 108584                           Rick Ross / Stay Schemin  ...       NaN
# 108585                   Pentatonix / Mary, Did You Know?  ...       NaN
# 108586            The Treblemakers / Don't Stop The Music  ...       NaN
# 108587               VaShawn Mitchell / Chasing After You  ...       NaN
# 108588               Of Monsters and Men / Mountain Sound  ...       NaN
# 108589                              Alina Baraz / Fantasy  ...       NaN
# 108590      Hillsong Young & Free / This Is Living - Live  ...       NaN
#
#        Track 219 Track 220 Track 221 Track 222 Track 223 Track 224 Track 225  \
# 108561       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108562       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108563       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108564       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108565       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108566       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108567       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108568       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108569       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108570       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108571       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108572       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108573       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108574       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108575       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108576       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108577       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108578       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108579       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108580       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108581       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108582       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108583       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108584       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108585       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108586       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108587       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108588       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108589       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 108590       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#        Track 226 Track 227
# 108561       NaN       NaN
# 108562       NaN       NaN
# 108563       NaN       NaN
# 108564       NaN       NaN
# 108565       NaN       NaN
# 108566       NaN       NaN
# 108567       NaN       NaN
# 108568       NaN       NaN
# 108569       NaN       NaN
# 108570       NaN       NaN
# 108571       NaN       NaN
# 108572       NaN       NaN
# 108573       NaN       NaN
# 108574       NaN       NaN
# 108575       NaN       NaN
# 108576       NaN       NaN
# 108577       NaN       NaN
# 108578       NaN       NaN
# 108579       NaN       NaN
# 108580       NaN       NaN
# 108581       NaN       NaN
# 108582       NaN       NaN
# 108583       NaN       NaN
# 108584       NaN       NaN
# 108585       NaN       NaN
# 108586       NaN       NaN
# 108587       NaN       NaN
# 108588       NaN       NaN
# 108589       NaN       NaN
# 108590       NaN       NaN
#
# [30 rows x 227 columns]

# %% [markdown]
# ### Verificando os valores nulos, é possível ver o número de nulos aumenta conforme o tamanho da playlist, como temos 108591 registros, podemos definir um número de músicas por playlist que mantenha pelo menos metade desses registros, eliminando os dados nulos da análise.

# %% [markdown]
# ### Poderia ser definido que todos os registros teriam apenas 5 musicas, pois não existe nenhum registro que não tenha pelo menos esse número de músicas
#
# ### Porém, é necessário um equilíbrio dos dados, pois com poucas informações sobre a playlist, o algoritmo de associação não vai ter um resultado tão bom.
#
# ### Sendo assim, será definido que o número de músicas em uma playlist será 66 (média de músicas por playlist), e com isso irá sobrar 40.356 dados para análise.

# %%
pd.set_option('display.max_rows', None)
new_df.isna().sum()
# Out:
# Track 1           0
# Track 2           0
# Track 3           0
# Track 4           0
# Track 5           0
# Track 6         600
# Track 7        1287
# Track 8        2037
# Track 9        2968
# Track 10       3937
# Track 11       5075
# Track 12       6258
# Track 13       7621
# Track 14       8932
# Track 15      10382
# Track 16      11898
# Track 17      13401
# Track 18      14885
# Track 19      16374
# Track 20      17877
# Track 21      19514
# Track 22      21128
# Track 23      22555
# Track 24      23984
# Track 25      25438
# Track 26      26899
# Track 27      28325
# Track 28      29680
# Track 29      31026
# Track 30      32336
# Track 31      33808
# Track 32      35122
# Track 33      36422
# Track 34      37690
# Track 35      38891
# Track 36      40076
# Track 37      41318
# Track 38      42473
# Track 39      43708
# Track 40      44855
# Track 41      46136
# Track 42      47206
# Track 43      48274
# Track 44      49385
# Track 45      50400
# Track 46      51403
# Track 47      52327
# Track 48      53311
# Track 49      54310
# Track 50      55247
# Track 51      56189
# Track 52      57110
# Track 53      58050
# Track 54      58945
# Track 55      59832
# Track 56      60654
# Track 57      61513
# Track 58      62305
# Track 59      63051
# Track 60      63824
# Track 61      64628
# Track 62      65341
# Track 63      66054
# Track 64      66808
# Track 65      67539
# Track 66      68235
# Track 67      68898
# Track 68      69556
# Track 69      70207
# Track 70      70859
# Track 71      71503
# Track 72      72167
# Track 73      72762
# Track 74      73374
# Track 75      73942
# Track 76      74543
# Track 77      75118
# Track 78      75691
# Track 79      76180
# Track 80      76728
# Track 81      77221
# Track 82      77787
# Track 83      78310
# Track 84      78769
# Track 85      79251
# Track 86      79725
# Track 87      80186
# Track 88      80630
# Track 89      81065
# Track 90      81527
# Track 91      81967
# Track 92      82404
# Track 93      82812
# Track 94      83279
# Track 95      83680
# Track 96      84095
# Track 97      84460
# Track 98      84843
# Track 99      85244
# Track 100     85642
# Track 101     86114
# Track 102     86486
# Track 103     86870
# Track 104     87264
# Track 105     87639
# Track 106     88004
# Track 107     88335
# Track 108     88649
# Track 109     89021
# Track 110     89358
# Track 111     89702
# Track 112     90010
# Track 113     90346
# Track 114     90687
# Track 115     90972
# Track 116     91285
# Track 117     91591
# Track 118     91908
# Track 119     92176
# Track 120     92478
# Track 121     92743
# Track 122     93033
# Track 123     93305
# Track 124     93564
# Track 125     93819
# Track 126     94079
# Track 127     94319
# Track 128     94593
# Track 129     94837
# Track 130     95059
# Track 131     95298
# Track 132     95510
# Track 133     95708
# Track 134     95944
# Track 135     96176
# Track 136     96418
# Track 137     96645
# Track 138     96851
# Track 139     97053
# Track 140     97285
# Track 141     97492
# Track 142     97701
# Track 143     97919
# Track 144     98118
# Track 145     98313
# Track 146     98502
# Track 147     98685
# Track 148     98870
# Track 149     99060
# Track 150     99282
# Track 151     99465
# Track 152     99652
# Track 153     99825
# Track 154     99995
# Track 155    100184
# Track 156    100340
# Track 157    100533
# Track 158    100709
# Track 159    100857
# Track 160    101023
# Track 161    101205
# Track 162    101365
# Track 163    101513
# Track 164    101658
# Track 165    101807
# Track 166    101984
# Track 167    102123
# Track 168    102283
# Track 169    102428
# Track 170    102569
# Track 171    102726
# Track 172    102871
# Track 173    103001
# Track 174    103133
# Track 175    103263
# Track 176    103406
# Track 177    103529
# Track 178    103656
# Track 179    103788
# Track 180    103921
# Track 181    104044
# Track 182    104161
# Track 183    104267
# Track 184    104408
# Track 185    104526
# Track 186    104629
# Track 187    104741
# Track 188    104851
# Track 189    104947
# Track 190    105050
# Track 191    105169
# Track 192    105284
# Track 193    105412
# Track 194    105525
# Track 195    105635
# Track 196    105737
# Track 197    105841
# Track 198    105939
# Track 199    106043
# Track 200    106156
# Track 201    106271
# Track 202    106385
# Track 203    106491
# Track 204    106594
# Track 205    106691
# Track 206    106776
# Track 207    106867
# Track 208    106973
# Track 209    107070
# Track 210    107147
# Track 211    107240
# Track 212    107330
# Track 213    107412
# Track 214    107497
# Track 215    107597
# Track 216    107665
# Track 217    107756
# Track 218    107847
# Track 219    107927
# Track 220    108006
# Track 221    108081
# Track 222    108136
# Track 223    108211
# Track 224    108295
# Track 225    108373
# Track 226    108445
# Track 227    108519
# dtype: int64

# %% [markdown]
# ### Para filtrar, possível percorrer todos os registros onde os valores não são nulos até a coluna "Track 49"

# %%
registros_sem_nulos = new_df.loc[:, :'Track 66'].dropna()

# %%
len(registros_sem_nulos)
# Out:
# 40356

# %% [markdown]
# ### Como é possível ver, agora temos 40356 registros sem valores nulos, o que melhora a eficácia do modelo

# %%
pd.set_option('display.max_rows', None)
registros_sem_nulos.isna().sum()
# Out:
# Track 1     0
# Track 2     0
# Track 3     0
# Track 4     0
# Track 5     0
# Track 6     0
# Track 7     0
# Track 8     0
# Track 9     0
# Track 10    0
# Track 11    0
# Track 12    0
# Track 13    0
# Track 14    0
# Track 15    0
# Track 16    0
# Track 17    0
# Track 18    0
# Track 19    0
# Track 20    0
# Track 21    0
# Track 22    0
# Track 23    0
# Track 24    0
# Track 25    0
# Track 26    0
# Track 27    0
# Track 28    0
# Track 29    0
# Track 30    0
# Track 31    0
# Track 32    0
# Track 33    0
# Track 34    0
# Track 35    0
# Track 36    0
# Track 37    0
# Track 38    0
# Track 39    0
# Track 40    0
# Track 41    0
# Track 42    0
# Track 43    0
# Track 44    0
# Track 45    0
# Track 46    0
# Track 47    0
# Track 48    0
# Track 49    0
# Track 50    0
# Track 51    0
# Track 52    0
# Track 53    0
# Track 54    0
# Track 55    0
# Track 56    0
# Track 57    0
# Track 58    0
# Track 59    0
# Track 60    0
# Track 61    0
# Track 62    0
# Track 63    0
# Track 64    0
# Track 65    0
# Track 66    0
# dtype: int64

# %% [markdown]
# ### Agora que temos os dados tratados, o próximo passo é converter em uma matriz, pois é assim que o modelo consegue ler os dados.

# %%
registros = []

num_colunas = 66

for linha in range(0, len(registros_sem_nulos)):
    registro_linha = []
    for coluna in range(0, num_colunas):
        registro_linha.append(registros_sem_nulos.iloc[linha, coluna])
    registros.append(registro_linha)

# %% [markdown]
# ### Para facilitar as próximas execuções, essa matriz será salva em um arquivo para posteriormente ser lida novamente.

# %%
with open('matrix.txt', 'w') as arquivo:
    json.dump(registros, arquivo)

# %%
import pandas as pd
import os
import numpy as np
import json
import random

# Ler a lista de volta do arquivo JSON
with open('matrix.txt', 'r') as arquivo:
    matriz = json.load(arquivo)

# %%
matriz[7][9]
# Out:
# 'Hospital / Right On'

# %% [markdown]
# ### Agora com a matriz em mãos, é possível executar o modelo importado da lib apyori e editar os parâmetros

# %% [markdown]
# ### - Definindo valores de suporte, confiança e Lift:

# %%
support = 0.0030
# Quero que uma associação occora pelo menos 150 vezes 
# na base de dados para entrar na regra, então uso esse valor para chegar em um valor aproximado

confidence = 0.005
# A medida de confiança define a probabilidade de ocorrência do consequente na transacao,
# dado que a transacao já contém os antecedentes. Porém, se o item consequente é muito popular na base de dados, ele irá 
# aparecer na maioria das transações, o que pode levar a uma análise incorreta, para corrigir isso, o LIFT é utilizado.

lift = 5
# O valor mais importante, geralmente é definido que é válido analisar associações onde esse valor é maior que 1.

#Explicação completa desses valores aqui -> https://towardsdatascience.com/association-rules-2-aa9a77241654

# %%
from apyori import apriori

arules = apriori(matriz,min_support=support, min_confidence=confidence,min_lift=lift)

association_results = list(arules)

len(association_results)
# Out:
# 16130

# %%
def frozenset_encoder(obj):
    if isinstance(obj, frozenset):
        return list(obj)
    raise TypeError(repr(obj) + " is not JSON serializable")

# %%
with open("arules.txt", "w") as file:
    json.dump(association_results, file, default=frozenset_encoder)

# %%
import pandas as pd
import os
import numpy as np
import json
import random

with open("arules.txt",'r') as arquivo_leitura:
    association_results = json.load(arquivo_leitura)

# %%
# len(association_results)
association_results[0]
# Out:
# [['*NSYNC / Bye Bye Bye', "*NSYNC / It's Gonna Be Me"],
#  0.003568242640499554,
#  [[['*NSYNC / Bye Bye Bye'],
#    ["*NSYNC / It's Gonna Be Me"],
#    0.2691588785046729,
#    53.773147034329604],
#   [["*NSYNC / It's Gonna Be Me"],
#    ['*NSYNC / Bye Bye Bye'],
#    0.7128712871287128,
#    53.7731470343296]]]

# %%
import pandas as pd
import os
import numpy as np
import json
import random

results = []
# conjuntos_filtrados = [conjunto for conjunto in association_results if '' not in conjunto]

for item in association_results:
    
    pair = item[0]
    items = [x for x in pair]
    
    value6 = items[0]+" & "+items[1]
    value0 = items[0]
    value1 = items[1]
    
    value2 = item[1]
    
    value3 = item[2][0][2]
    value4 = item[2][0][3]
    
    rows = (value6,value0,value1,value2,value3,value4)
    results.append(rows)
    
labels = ["Associação","Musica 1","Musica 2", "Support", "Confidence","Lift"]

music_suggestion = pd.DataFrame.from_records(results,columns=labels)

# %%
len(music_suggestion)
# Out:
# 16130

# %%
music_suggestion.drop_duplicates(subset=['Musica 1', 'Musica 2'], inplace=True)

# %%
music_suggestion.sort_values(by='Lift',ascending=False)
# Out:
#                                               Associação  \
# 9692   Michael Bublé / White Christmas (Duet With Sha...
# 10753  Michael Bublé / I'll Be Home For Christmas & M...
# 10920  Michael Bublé / Blue Christmas & Michael Bublé...
# 10913  Michael Bublé / Blue Christmas & Michael Bublé...
# 10755  Michael Bublé / Blue Christmas & Michael Bublé...
# ...                                                  ...
# 734           Drake / Controlla & Big Sean / Bounce Back
# 1322   J. Cole / Wet Dreamz & Chance The Rapper / No ...
# 2283               Drake / Jumpman & Flo Rida / My House
# 4955   Waka Flocka Flame / No Hands (feat. Roscoe Das...
# 5433        Rob $tone / Chill Bill & Rihanna / Needed Me
#
#                                                 Musica 1  \
# 9692   Michael Bublé / White Christmas (Duet With Sha...
# 10753         Michael Bublé / I'll Be Home For Christmas
# 10920                     Michael Bublé / Blue Christmas
# 10913                     Michael Bublé / Blue Christmas
# 10755                     Michael Bublé / Blue Christmas
# ...                                                  ...
# 734                                    Drake / Controlla
# 1322                                J. Cole / Wet Dreamz
# 2283                                     Drake / Jumpman
# 4955   Waka Flocka Flame / No Hands (feat. Roscoe Das...
# 5433                              Rob $tone / Chill Bill
#
#                                                 Musica 2   Support  \
# 9692                        Michael Bublé / Silent Night  0.003197
# 10753                       Michael Bublé / Silent Night  0.003197
# 10920  Michael Bublé / It's Beginning To Look A Lot L...  0.003271
# 10913  Michael Bublé / Jingle Bells (feat. The Puppin...  0.003197
# 10755  Michael Bublé / Christmas (Baby Please Come Home)  0.003172
# 5136            Nirvana / Smells Like Teen Spirit  0.003618    0.203911
# 3332          Guns N' Roses / Sweet Child O' Mine  0.003692    0.177170
# 5131            Nirvana / Smells Like Teen Spirit  0.003271    0.184358
# 5135                           Sublime / Santeria  0.003048    0.171788
# 5132  Queen / Bohemian Rhapsody - Remastered 2011  0.003122    0.175978
#
#            Lift
# 5130  37.575419
# 5127  34.414026
# 5129  33.446252
# 4838  16.948353
# 3077  16.908939
# 5133  13.492991
# 5134  13.280513
# 5136  10.456184
# 3332   9.985857
# 5131   8.910099
# 5135   8.454469
# 5132   6.606283

# %% [markdown]
# ### Com as associações acima, é possível perceber que uma pessoa que gosta do gênero com certeza iria curtir algumas dessas recomendações.

# %% [markdown]
# ### Outro exemplo, se a pessoa ouviu o artista X, quais artistas ela pode gostar?

# %%
def split_string(input_string,part):
    # Count occurrences of "/"
    count_slash = input_string.count("/")
    # If there's more than one occurrence
    if  "AC / DC" in input_string:
        # Find the position of the second occurrence of "/"
        second_slash_index = input_string.find("/", input_string.find("/") + 1)
        # Split at the position of the second occurrence
        return "/".join(input_string.split("/", 2)[:2])
    else:
        # Split normally
        return input_string.split("/")[part].strip()

# %%
split_string("AC / DC / ...",0)
# Out:
# 'AC / DC '

# %%
df_artistas_sorted = sorted_suggestions
df_artistas_sorted['Artista 1'] = df_artistas_sorted['Musica 1'].apply(lambda x: split_string(x, 0))
df_artistas_sorted['Artista 2'] = df_artistas_sorted['Musica 2'].apply(lambda x: split_string(x, 0))
df_artistas_sorted['Musica 1'] = df_artistas_sorted['Musica 1'].apply(lambda x: split_string(x, 1))
df_artistas_sorted['Musica 2'] = df_artistas_sorted['Musica 2'].apply(lambda x: split_string(x, 1))

df_artistas_sorted = df_artistas_sorted[['Associação', 'Musica 1', 'Musica 2', 'Artista 1', 'Artista 2', 'Support','Confidence','Lift']] 

df_artistas_sorted
# Out:
#                                               Associação  \
# 9692   Michael Bublé / White Christmas (Duet With Sha...
# 10753  Michael Bublé / I'll Be Home For Christmas & M...
# 10920  Michael Bublé / Blue Christmas & Michael Bublé...
# 10913  Michael Bublé / Blue Christmas & Michael Bublé...
# 10755  Michael Bublé / Blue Christmas & Michael Bublé...
# ...                                                  ...
# 734           Drake / Controlla & Big Sean / Bounce Back
# 1322   J. Cole / Wet Dreamz & Chance The Rapper / No ...
# 2283               Drake / Jumpman & Flo Rida / My House
# 4955   Waka Flocka Flame / No Hands (feat. Roscoe Das...
# 5433        Rob $tone / Chill Bill & Rihanna / Needed Me
#
#                                                 Musica 1  \
# 9692            White Christmas (Duet With Shania Twain)
# 10753                         I'll Be Home For Christmas
# 10920                                     Blue Christmas
# 10913                                     Blue Christmas
# 10755                                     Blue Christmas
# ...                                                  ...
# 734                                            Controlla
# 1322                                          Wet Dreamz
# 2283                                             Jumpman
# 4955   No Hands (feat. Roscoe Dash and Wale) - Explic...
# 5433                                          Chill Bill
#
#                                           Musica 2          Artista 1  \
# 9692                                  Silent Night      Michael Bublé
# 10753                                 Silent Night      Michael Bublé
# 10920  It's Beginning To Look A Lot Like Christmas      Michael Bublé
# 10913     Jingle Bells (feat. The Puppini Sisters)      Michael Bublé
# 10755            Christmas (Baby Please Come Home)      Michael Bublé
# ...                                            ...                ...
# 734                                    Bounce Back              Drake
# 1322       No Problem (feat. Lil Wayne & 2 Chainz)            J. Cole
# 2283                                      My House              Drake
# 4955           Bad and Boujee (feat. Lil Uzi Vert)  Waka Flocka Flame
# 5433                                     Needed Me          Rob $tone
#
#                Artista 2   Support  Confidence        Lift
# 9692       Michael Bublé  0.003197    0.791411  236.579141
# 10753      Michael Bublé  0.003197    0.791411  233.125431
# 10920      Michael Bublé  0.003271    0.809816  231.779663
# 10913      Michael Bublé  0.003197    0.791411  231.436116
# 10755      Michael Bublé  0.003172    0.785276  231.318257
# ...                  ...       ...         ...         ...
# 734             Big Sean  0.003890    0.115356    5.011110
# 1322   Chance The Rapper  0.003841    0.117960    5.010959
# 2283            Flo Rida  0.004336    0.118805    5.009928
# 4955               Migos  0.004138    0.117193    5.004698
# 5433             Rihanna  0.003444    0.128111    5.000030
#
# [6110 rows x 8 columns]

# %%
def busca_artistas(artista):
    df_matches = df_artistas_sorted[(df_artistas_sorted['Artista 1'] == artista) | (df_artistas_sorted['Artista 2'] == artista)]

    # split_by_slash = lambda x: x.split("/")[0]
    df_matches['Recomendacoes'] = df_matches['Artista 1'] + df_matches['Artista 2']
    df_artistas =  df_matches['Recomendacoes']
    return df_artistas

# %%
artista = "Guns N' Roses"
x=busca_artistas(artista)

# removed_searched_band = lambda x, artist: [item for item in x if item != artist]

artists_list_filtered = [artist.replace(artista, '').strip() for artist in x]

artists_list_filtered = list(filter(None, artists_list_filtered))
artists_list_filtered = list(set(artists_list_filtered))

artists_list_filtered
# Out:
# C:\Users\pcozz\AppData\Local\Temp\ipykernel_14608\1935377541.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ['Lynyrd Skynyrd',
#  'Def Leppard',
#  'Kansas',
#  'Nirvana',
#  'Aerosmith',
#  'Van Halen',
#  'Neil Diamond',
#  'Bryan Adams',
#  'Ozzy Osbourne',
#  'AC',
#  'Metallica',
#  'KISS',
#  'Boston',
#  'Journey',
#  'Queen',
#  'Billy Joel',
#  'The Rolling Stones',
#  'The Animals',
#  'Creedence Clearwater Revival',
#  'Led Zeppelin',
#  'Rick Springfield',
#  'Van Morrison',
#  'Eagles',
#  'Survivor',
#  'Bon Jovi',
#  'Elton John']

# %%
print(artists_list_filtered)
# Out:
# ['Lynyrd Skynyrd', 'Def Leppard', 'Kansas', 'Nirvana', 'Aerosmith', 'Van Halen', 'Neil Diamond', 'Bryan Adams', 'Ozzy Osbourne', 'AC', 'Metallica', 'KISS', 'Boston', 'Journey', 'Queen', 'Billy Joel', 'The Rolling Stones', 'The Animals', 'Creedence Clearwater Revival', 'Led Zeppelin', 'Rick Springfield', 'Van Morrison', 'Eagles', 'Survivor', 'Bon Jovi', 'Elton John']
